# %%
import pandas as pd
import numpy as np

RawData=pd.read_csv('/Users/kurakulaenus/Desktop/A - Python/C - Projects/B - OriginalData/VGProject-main/VideoGamesSales.csv',encoding='latin1')
RawData
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %%
df=RawData.copy()
df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Month', 'Genre', 'Publisher',
#        'Country', 'City', 'State', 'Region', 'NA_Sales', 'Global_Sales',
#        'NA_Profit', 'Global_Profit'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5909, step=1)

# %%
df.shape
# Out:
# (5909, 15)

# %%
df.dtypes
# Out:
# Rank               int64
# Name              object
# Platform          object
# Year               int64
# Month             object
# Genre             object
# Publisher         object
# Country           object
# City              object
# State             object
# Region            object
# NA_Sales          object
# Global_Sales     float64
# NA_Profit        float64
# Global_Profit    float64
# dtype: object

# %%
df.head(5)
# Out:
#    Rank                      Name Platform  Year Month         Genre  \
# 0     1                Wii Sports      Wii  2010   Jan        Sports
# 1     2         Super Mario Bros.      NES  2010   Feb      Platform
# 2     3            Mario Kart Wii      Wii  2010   Mar        Racing
# 3     4         Wii Sports Resort      Wii  2010   Apr        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB  2010   May  Role-Playing
#
#   Publisher        Country        City       State   Region NA_Sales  \
# 0  Nintendo  United States   Fairfield  California     West   $41.49
# 1  Nintendo  United States     Edmonds  Washington     West   $29.08
# 2  Nintendo  United States  Louisville    Kentucky    South   $15.85
# 3  Nintendo  United States  Round Rock       Texas  Central   $15.75
# 4  Nintendo  United States   Nashville   Tennessee    South   $11.27
#
#    Global_Sales  NA_Profit  Global_Profit
# 0         82.74     12.447         24.822
# 1         40.24      8.724         12.072
# ...

# %%
df.tail(5)
# Out:
#       Rank                                       Name Platform  Year Month  \
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#            Genre           Publisher    Country    City            State  \
# 5904      Racing                 THQ  Australia  Sydney  New South Wales
# 5905  Simulation     Electronic Arts  Australia  Sydney  New South Wales
# 5906      Action     Electronic Arts  Australia  Sydney  New South Wales
# 5907      Action          Activision  Australia  Sydney  New South Wales
# 5908  Simulation  Namco Bandai Games  Australia  Sydney  New South Wales
#
#      Region NA_Sales  Global_Sales  NA_Profit  Global_Profit
# ...

# %%
df.sample(5)
# Out:
#       Rank                             Name Platform  Year Month       Genre  \
# 1703  1692        Pro Evolution Soccer 2008      Wii  2011   Nov      Sports
# 1627  1619           Farming Simulator 2015       PC  2015   Oct  Simulation
# 2203  2192        Army of Two: The 40th Day     X360  2012   Jul     Shooter
# 5313  5302        Hannah Montana: The Movie      Wii  2016   Sep   Adventure
# 5535  5524  Warhammer 40,000: Squad Command      PSP  2017   Mar    Strategy
#
#                          Publisher        Country           City  \
# 1703  Konami Digital Entertainment  United States  New York City
# 1627        Focus Home Interactive  United States  Oklahoma City
# 2203               Electronic Arts  United States   Newport News
# 5313    Disney Interactive Studios      Australia         Sydney
# 5535                           THQ      Australia         Sydney
#
#                 State   Region NA_Sales  Global_Sales  NA_Profit  \
# ...

# %%
df.nunique()
# Out:
# Rank             5893
# Name             4139
# Platform           26
# Year                8
# Month              14
# Genre              12
# Publisher         219
# Country             3
# City              391
# State              56
# Region              6
# NA_Sales          420
# Global_Sales      594
# NA_Profit         409
# Global_Profit     594
# dtype: int64

# %%
df.value_counts()
# Out:
# Rank  Name                                                 Platform  Year  Month  Genre       Publisher                    Country        City       State            Region  NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 9     New Super Mario Bros. Wii                            Wii       2010  Sep    Platform    Nintendo                     USA            Fairfield  Ohio             East    $14.59    28.62         4.377      8.586            5
# 373   Donkey Kong Country 3: Dixie Kong's Double Trouble!  SNES      2010  Jan    Platform    Nintendo                     United States  Lancaster  Ohio             East    1.17      3.51          0.351      1.053            4
# 60    Super Mario 64                                       DS        2010  Dec    Platform    Nintendo                     United States  Seattle    Washington       West    5.08      10.42         1.524      3.126            4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5909 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5909 non-null   int64
#  1   Name           5909 non-null   object
#  2   Platform       5909 non-null   object
#  3   Year           5909 non-null   int64
#  4   Month          5909 non-null   object
#  5   Genre          5909 non-null   object
#  6   Publisher      5897 non-null   object
#  7   Country        5909 non-null   object
#  8   City           5909 non-null   object
#  9   State          5909 non-null   object
#  10  Region         5882 non-null   object
#  11  NA_Sales       5909 non-null   object
#  12  Global_Sales   5909 non-null   float64
#  13  NA_Profit      5909 non-null   float64
#  14  Global_Profit  5909 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 692.6+ KB

# %%
df.describe()
# Out:
#               Rank         Year  Global_Sales    NA_Profit  Global_Profit
# count  5909.000000  5909.000000   5909.000000  5909.000000    5909.000000
# mean   2943.953461  2013.197834      1.344519     0.198809       0.403356
# std    1704.649477     2.223609      2.526125     0.400008       0.757837
# min       1.000000  2010.000000      0.300000     0.000000       0.090000
# 25%    1469.000000  2011.000000      0.440000     0.060000       0.132000
# 50%    2943.000000  2013.000000      0.690000     0.108000       0.207000
# 75%    4420.000000  2015.000000      1.330000     0.204000       0.399000
# max    5894.000000  2017.000000     82.740000    12.447000      24.822000

# %% [markdown]
# # RESTART

# %%
df=RawData.copy()
df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5909 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5909 non-null   int64
#  1   Name           5909 non-null   object
#  2   Platform       5909 non-null   object
#  3   Year           5909 non-null   int64
#  4   Month          5909 non-null   object
#  5   Genre          5909 non-null   object
#  6   Publisher      5897 non-null   object
#  7   Country        5909 non-null   object
#  8   City           5909 non-null   object
#  9   State          5909 non-null   object
#  10  Region         5882 non-null   object
#  11  NA_Sales       5909 non-null   object
#  12  Global_Sales   5909 non-null   float64
#  13  NA_Profit      5909 non-null   float64
#  14  Global_Profit  5909 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 692.6+ KB

# %% [markdown]
# # check and drop_duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(16)

# %%
df[df.duplicated()]
# Out:
#       Rank                                               Name Platform  Year  \
# 9        9                          New Super Mario Bros. Wii      Wii  2010
# 10       9                          New Super Mario Bros. Wii      Wii  2010
# 11       9                          New Super Mario Bros. Wii      Wii  2010
# 12       9                          New Super Mario Bros. Wii      Wii  2010
# 64      60                                     Super Mario 64       DS  2010
# 65      60                                     Super Mario 64       DS  2010
# 66      60                                     Super Mario 64       DS  2010
# 380    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 381    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 382    373  Donkey Kong Country 3: Dixie Kong's Double Tro...     SNES  2010
# 1658  1649                                         WCW Mayhem       PS  2015
# ...

# %%
df.shape
# Out:
# (5909, 15)

# %%
# Count duplicates per column
for col in df.columns:
    print(col, df[col].duplicated().sum())
# Out:
# Rank 16
# Name 1770
# Platform 5883
# Year 5901
# Month 5895
# Genre 5897
# Publisher 5689
# Country 5906
# City 5518
# State 5853
# Region 5902
# NA_Sales 5489
# Global_Sales 5315
# NA_Profit 5500
# Global_Profit 5315

# %%
# If we have duplicates then give all columns to drop them
df.drop_duplicates(inplace=True)  
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pd.set_option('display.max_rows',None)
df[df['Name'].duplicated()]
# Out:
#       Rank                                               Name Platform  Year  \
# 27      24                                 Grand Theft Auto V     X360  2010
# 39      36                         Call of Duty: Black Ops II     X360  2010
# 41      38                     Call of Duty: Modern Warfare 3      PS3  2010
# 44      41                            Call of Duty: Black Ops      PS3  2010
# 48      45                                 Grand Theft Auto V      PS4  2010
# 59      56                     Call of Duty: Modern Warfare 2      PS3  2010
# 60      57                                Grand Theft Auto IV      PS3  2010
# 63      60                                     Super Mario 64       DS  2010
# 74      68                               Call of Duty: Ghosts      PS3  2010
# 108    102                          Call of Duty: Black Ops 3     XOne  2010
# 110    104                                      Battlefield 3      PS3  2010
# ...

# %%
pd.reset_option('display.max_rows')

# %%
# Look at in the all columns and Except Rank check once duplicates for remaining columns if you have delete it or think rank how rank is important
cols=df.columns.drop('Rank') # Here Rank is ignouring
cols
# Out:
# Index(['Name', 'Platform', 'Year', 'Month', 'Genre', 'Publisher', 'Country',
#        'City', 'State', 'Region', 'NA_Sales', 'Global_Sales', 'NA_Profit',
#        'Global_Profit'],
#       dtype='object')

# %%
df.duplicated(subset=cols).sum()
# Out:
# np.int64(0)

# %%
# If we have duplicates then give all columns to drop them like 
# df.drop_duplicates(subset=cols, keep='first', inplace=True)
# df.duplicated(subset=cols).sum()

# %%
df.shape # After droping 16 duplicate Total 5909 - 16 = 5893
# Out:
# (5893, 15)

# %% [markdown]
# # Now Check Null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5893 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5893 non-null   int64
#  1   Name           5893 non-null   object
#  2   Platform       5893 non-null   object
#  3   Year           5893 non-null   int64
#  4   Month          5893 non-null   object
#  5   Genre          5893 non-null   object
#  6   Publisher      5881 non-null   object
#  7   Country        5893 non-null   object
#  8   City           5893 non-null   object
#  9   State          5893 non-null   object
#  10  Region         5866 non-null   object
#  11  NA_Sales       5893 non-null   object
#  12  Global_Sales   5893 non-null   float64
#  13  NA_Profit      5893 non-null   float64
#  14  Global_Profit  5893 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 736.6+ KB

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year              0
# Month             0
# Genre             0
# Publisher        12
# Country           0
# City              0
# State             0
# Region           27
# NA_Sales          0
# Global_Sales      0
# NA_Profit         0
# Global_Profit     0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# np.int64(39)

# %%
df[df.isna().any(axis=1)]
# Out:
#       Rank                                               Name Platform  Year  \
# 13      10                                          Duck Hunt      NES  2010
# 38      35                         Call of Duty: Black Ops II      PS3  2010
# 53      50          Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2010
# 84      78                                            FIFA 16      PS4  2010
# 126    120                         Uncharted 2: Among Thieves      PS3  2010
# 210    204                Super Smash Bros. for Wii U and 3DS     WiiU  2010
# 225    219                                   Assassin's Creed      PS3  2010
# 243    237                                     The Last of Us      PS4  2010
# 480    471                         wwe Smackdown vs. Raw 2006      PS2  2010
# 1313  1305                                     Triple Play 99       PS  2013
# 1675  1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA  2011
# ...

# %%
df.dropna() # After dropping 12+27=39 Null value Total= 5893 - 39=5854
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      Wii  2010   Jan
# 1        2                          Super Mario Bros.      NES  2010   Feb
# 2        3                             Mario Kart Wii      Wii  2010   Mar
# 3        4                          Wii Sports Resort      Wii  2010   Apr
# 4        5                   Pokemon Red/Pokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                   Crazy Taxi: Catch a Ride      GBA  2017   Sep
# 5905  5891                               MySims Party       DS  2017   Oct
# 5906  5892  Harry Potter and the Order of the Phoenix     X360  2017   Nov
# 5907  5893                  Skylanders: SuperChargers      PS4  2017   Dec
# 5908  5894               Macross Digital Mission VF-X       PS  2017   Jan
#
#              Genre           Publisher        Country        City  \
# ...

# %% [markdown]
# # 1> Name

# %%
# '', '  ', ., :, /, &, +, -, ', (2015), !, 

import numpy as np
df['Name'] = (
    df['Name']
    .astype('string')
    .str.strip()
    .str.lower()
    .str.replace(r"[^a-zA-Z0-9\s]", '', regex=True)    # keeps only letters,numbers
    .str.replace(r'\s+', ' ', regex=True)              # collapse multiple spaces
    .str.strip()                                       # strip
    .replace(r'^\s*$', np.nan, regex=True)
    .str.title()                                       # capitalize words
)
df['Name'].sample(10)
# Out:
# 5220               Sabans Power Rangers Lightspeed Rescue
# 1007                                    Hitman Absolution
# 3761                                               Popeye
# 1298                                           Mario Golf
# 1019                                      Disneys Aladdin
# 234                  The Lord Of The Rings The Two Towers
# 1749                                         Mirrors Edge
# 4777                           Marvel Ultimate Alliance 2
# 1908    Spongebob Squarepants Revenge Of The Flying Du...
# 1544                                Guitar Hero Aerosmith
# Name: Name, dtype: string

# %% [markdown]
# # 2>  category platform ->

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS'], dtype=object)

# %%
df['Platform']=(df['Platform']
    .str.strip()
    .str.lower()
    .replace(r'^\s*$', np.nan, regex=True)
    .str.upper()
    .astype('category')
               )

df['Platform'].sample(10)
# Out:
# 5012     PSP
# 2650      DS
# 3301      XB
# 107      WII
# 5896      DS
# 5570      GC
# 5487      XB
# 2933    WIIU
# 2940     PS2
# 2111     PS3
# Name: Platform, dtype: category
# Categories (26, object): ['2600', '3DS', 'DC', 'DS', ..., 'WS', 'X360', 'XB', 'XONE']

# %% [markdown]
# # Year int64 - we dont need change any values because no null values and data type is int64 so it cleaned

# %%
df['Year'].sample(50)
# Out:
# 2379    2012
# 3684    2014
# 518     2010
# 1666    2011
# 5360    2016
# 4645    2015
# 3096    2011
# 4812    2016
# 2303    2012
# 4203    2015
# 5800    2017
# 585     2010
# 2825    2010
# 305     2010
# 1217    2012
# 2160    2012
# 4300    2015
# 981     2011
# 4517    2015
# 3672    2014
# 4876    2016
# 4043    2014
# 1385    2014
# 4903    2016
# 3686    2014
# 1444    2014
# 4061    2014
# 1196    2012
# 2855    2010
# 3830    2014
# 4102    2014
# 1030    2011
# 5841    2017
# 3369    2012
# 4060    2014
# 2903    2011
# 2258    2012
# 40      2010
# 37      2010
# 2264    2012
# 843     2011
# 1965    2012
# 1724    2011
# 5511    2017
# 4237    2015
# 2850    2010
# 3268    2012
# 2336    2012
# 3663    2014
# 2675    2014
# Name: Year, dtype: int64

# %% [markdown]
# # Month

# %%
df['Month'].unique()
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'October', 'November'], dtype=object)

# %%
pd.set_option('display.max_rows',None)
df['Month'] # Eg:- index 268 see October , index 3767 see Novermber so change it to Oct,Nov
# Out:
# 0            Jan
# 1            Feb
# 2            Mar
# 3            Apr
# 4            May
# 5            Jun
# 6            Jul
# 7            Aug
# 8            Sep
# 13           Oct
# 14           Nov
# 15           Dec
# 16           Jan
# 17           Feb
# 18           Mar
# 19           Apr
# 20           May
# 21           Jun
# 22           Jul
# 23           Aug
# 24           Sep
# 25           Oct
# 26           Nov
# 27           Dec
# 28           Jan
# 29           Feb
# 30           Mar
# 31           Apr
# 32           May
# 33           Jun
# 34           Jul
# 35           Aug
# 36           Sep
# 37           Oct
# 38           Nov
# 39           Dec
# 40           Jan
# 41           Feb
# 42           Mar
# 43           Apr
# 44           May
# 45           Jun
# 46           Jul
# 47           Aug
# 48           Sep
# 49           Oct
# 50           Nov
# 51           Dec
# 52           Jan
# 53           Feb
# 54           Mar
# 55           Apr
# ...

# %%
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'October', 'November'], dtype=object)

# o-c :-  october,november -> ,Oct, Nov
df['Month']=(df['Month']
    .astype('string')
    .str.strip()
    .str.lower()
    .replace({'october':'oct', 'november':'nov'})
    .str.capitalize()
    .astype('category')
            )

# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, string): [Apr, Aug, Dec, Feb, ..., May, Nov, Oct, Sep]

# valid_month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec']

# df.loc[~df['Month'].isin(valid_month), 'Month']=np.nan

df['Month']
# Eg:- index 268 see October , index 3767 see Novermber so change it to Oct,Nov
# Out:
# 0       Jan
# 1       Feb
# 2       Mar
# 3       Apr
# 4       May
# 5       Jun
# 6       Jul
# 7       Aug
# 8       Sep
# 13      Oct
# 14      Nov
# 15      Dec
# 16      Jan
# 17      Feb
# 18      Mar
# 19      Apr
# 20      May
# 21      Jun
# 22      Jul
# 23      Aug
# 24      Sep
# 25      Oct
# 26      Nov
# 27      Dec
# 28      Jan
# 29      Feb
# 30      Mar
# 31      Apr
# 32      May
# 33      Jun
# 34      Jul
# 35      Aug
# 36      Sep
# 37      Oct
# 38      Nov
# 39      Dec
# 40      Jan
# 41      Feb
# 42      Mar
# 43      Apr
# 44      May
# 45      Jun
# 46      Jul
# 47      Aug
# 48      Sep
# 49      Oct
# 50      Nov
# 51      Dec
# 52      Jan
# 53      Feb
# 54      Mar
# 55      Apr
# 56      May
# 57      Jun
# 58      Jul
# 59      Aug
# 60      Sep
# 61      Oct
# 62      Nov
# 63      Dec
# 67      Jan
# 68      Feb
# 69      Mar
# 70      Apr
# 71      May
# 72      Jun
# 73      Jul
# 74      Aug
# 75      Sep
# 76      Oct
# 77      Nov
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df['Month'].unique()
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, string): [Apr, Aug, Dec, Feb, ..., May, Nov, Oct, Sep]

# %%
valid_month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
       'Oct', 'Nov', 'Dec']

# %%
df.loc[~df['Month'].isin(valid_month), 'Month']=np.nan
df['Month'].sample(10)
# Out:
# 5905    Oct
# 1344    Mar
# 5523    Mar
# 1387    Oct
# 5265    Sep
# 4322    Feb
# 196     Oct
# 3465    Sep
# 3559    Jul
# 3024    Dec
# Name: Month, dtype: category
# Categories (12, string): [Apr, Aug, Dec, Feb, ..., May, Nov, Oct, Sep]

# %% [markdown]
# # 4> Genre

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

#  genre object o - c = Role-Playing -> Role Playing

df['Genre']=(df['Genre']
             .astype('string')
             .str.strip()
             .str.lower()
             .str.replace('-', ' ', regex=True)
             .replace(r'^\s*$', np.nan, regex=True)
             .str.title()
             .astype('category')
            )

# ['Sports', 'Platform', 'Racing', 'Role Playing', 'Puzzle', ..., 'Simulation', 'Action', 'Fighting', 'Adventure', 'Strategy']
# Length: 12
# Categories (12, string): [Action, Adventure, Fighting, Misc, ..., Shooter, Simulation, Sports, Strategy]


# valid_gerne=['Sports', 'Platform', 'Racing', 'Role Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy']

# df.loc[~df['Genre'].isin(valid_gerne), 'Genre']=np.nan

df['Genre'].sample(15)
# Out:
# 801         Sports
# 1225        Sports
# 4404      Strategy
# 5374      Platform
# 4920        Sports
# 651         Racing
# 125        Shooter
# 2884        Racing
# 5481    Simulation
# 1330      Strategy
# 2529        Action
# 1788          Misc
# 5447     Adventure
# 2273     Adventure
# 5669     Adventure
# Name: Genre, dtype: category
# Categories (12, string): [Action, Adventure, Fighting, Misc, ..., Shooter, Simulation, Sports, Strategy]

# %%
df['Genre'].unique()
# Out:
# ['Sports', 'Platform', 'Racing', 'Role Playing', 'Puzzle', ..., 'Simulation', 'Action', 'Fighting', 'Adventure', 'Strategy']
# Length: 12
# Categories (12, string): [Action, Adventure, Fighting, Misc, ..., Shooter, Simulation, Sports, Strategy]

# %%
valid_gerne=['Sports', 'Platform', 'Racing', 'Role Playing', 'Puzzle', 'Misc',
       'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
       'Strategy']

# %%
df.loc[~df['Genre'].isin(valid_gerne), 'Genre']=np.nan

df['Genre'].sample(15)
# Out:
# 121        Shooter
# 3195          Misc
# 1751        Puzzle
# 3545        Action
# 3833          Misc
# 5833    Simulation
# 3473        Sports
# 1090    Simulation
# 5006        Action
# 4937      Strategy
# 4841        Sports
# 1502      Fighting
# 4269      Platform
# 5316      Platform
# 3066        Sports
# Name: Genre, dtype: category
# Categories (12, string): [Action, Adventure, Fighting, Misc, ..., Shooter, Simulation, Sports, Strategy]

# %% [markdown]
# # 5> Publisher object - [-.,] [N/A, Unknown]

# %%
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
df['Publisher']=(df['Publisher']
                .astype('string')
                 .str.strip()
                 .str.lower()
                 .replace(r'[^a-zA-A0-9\s]', ' ', regex=True)
                 .replace(r'\s+', ' ', regex=True)
                 .replace(r'^\s*$', np.nan,regex=True)
                 .replace(['n/a','unknown'], np.nan)
                 .str.strip()
                 .str.title()
                 .astype('category')
                )

df['Publisher'].sample(10)
# Out:
# 4950           Sony Computer Entertainment
# 865                               Nintendo
# 649           Konami Digital Entertainment
# 4166                          Midway Games
# 1239                                  Sega
# 2838                               Ubisoft
# 1603                                 Atari
# 2729                       Electronic Arts
# 1960                       Electronic Arts
# 723     Sony Computer Entertainment Europe
# Name: Publisher, dtype: category
# Categories (218, string): [20Th Century Fox Video Games, 3Do, 505 Games, 989 Sports, ..., Xseed Games, Zoo Digital Publishing, Zoo Games, Zushi Games]

# %%
df['Publisher'].unique()
# Out:
# ['Nintendo', 'Microsoft Game Studios', 'Take Two Interactive', 'Sony Computer Entertainment', 'Activision', ..., 'Storm City Games', 'Cokem Interactive', 'Cbs Electronics', 'Magix', 'Marvelous Interactive']
# Length: 219
# Categories (218, string): [20Th Century Fox Video Games, 3Do, 505 Games, 989 Sports, ..., Xseed Games, Zoo Digital Publishing, Zoo Games, Zushi Games]

# %% [markdown]
# # Country

# %%
df['Country'].unique()
# Out:
# array(['United States', 'USA', 'Australia'], dtype=object)

# %%
# Here i am we have 3 countries like USA, United States, Australia so replace United States make as USA

df['Country']=(df['Country']
               .astype('string')
               .str.strip()
               .replace({'United States':'USA'}, regex=True)
               .str.strip()
               .replace(r'^\s*$',np.nan, regex=True)
               .astype('category')
)
df['Country'].sample(30)
# Out:
# 3218    Australia
# 5337    Australia
# 4763    Australia
# 3938    Australia
# 1313          USA
# 831           USA
# 2872    Australia
# 5067    Australia
# 2251          USA
# 5518    Australia
# 4777    Australia
# 3004    Australia
# 2124          USA
# 886           USA
# 893           USA
# 4471    Australia
# 3530    Australia
# 5365    Australia
# 4588    Australia
# 4637    Australia
# 4750    Australia
# 1860          USA
# 3678    Australia
# 2322          USA
# 309           USA
# 5853    Australia
# 2341          USA
# 2506          USA
# 1391          USA
# 334           USA
# Name: Country, dtype: category
# Categories (2, string): [Australia, USA]

# %%
df['Country'].unique()
# Out:
# ['USA', 'Australia']
# Categories (2, string): [Australia, USA]

# %%
valid_country=['USA','Australia']

# %%
df.loc[~df['Country'].isin(valid_country), 'Country']=np.nan
df['Country'].sample(30)
# Out:
# 1792          USA
# 2291          USA
# 1983          USA
# 2524          USA
# 3488    Australia
# 1557          USA
# 2955    Australia
# 4259    Australia
# 2790          USA
# 2288          USA
# 2013          USA
# 4315    Australia
# 89            USA
# 1555          USA
# 4469    Australia
# 5149    Australia
# 1468          USA
# 1406          USA
# 4780    Australia
# 3061    Australia
# 2554          USA
# 3439    Australia
# 2310          USA
# 4332    Australia
# 591           USA
# 2064          USA
# 1194          USA
# 5433    Australia
# 80            USA
# 4267    Australia
# Name: Country, dtype: category
# Categories (2, string): [Australia, USA]

# %% [markdown]
# # City

# %%
df['City'].unique()
# Out:
# array(['Fairfield', 'Edmonds', 'Louisville', 'Round Rock', 'Nashville',
#        'Newark', 'Fremont', 'Odessa', 'Dallas', 'Los Angeles',
#        'New Bedford', 'Little Rock', 'Lafayette', 'New York City',
#        'San Francisco', 'Milwaukee', 'Oceanside', 'Tulsa', 'Inglewood',
#        'San Diego', 'Skokie', 'Lawrence', 'Philadelphia', 'Jackson',
#        'Stockton', 'Houston', 'Cincinnati', 'Phoenix', 'Richmond',
#        'Madison', 'Toledo', 'Seattle', 'Chicago', 'Thornton',
#        'Charlottesville', 'Tampa', 'Denver', 'El Paso', 'Chattanooga',
#        'Baltimore', 'Asheville', 'Atlanta', 'Columbus', 'Rockford',
#        'Charlotte', 'Westminster', 'Carrollton', 'San Antonio',
#        'Homestead', 'Long Beach', 'Miramar', 'Hillsboro', 'Hagerstown',
#        'Roseville', 'Bowling Green', 'Pasadena', 'Springfield',
#        'Glendale', 'Garland', 'Tucson', 'Pasco', 'Brentwood',
#        'Fayetteville', 'Farmington', 'Greenwood', 'Eagan', 'Wilmington',
# ...

# %%
df['City']=(df['City']
            .astype('string')
            .str.strip()
            .str.lower()
            .str.replace('-',' ', regex=True)
            .str.replace(r'\s+', ' ', regex=True)
            .str.strip()
            .str.title()
            .replace({'Mcallen':'McAllen'})
            .replace(r'^\s*$', np.nan, regex=True)
            .astype('category')
            
           )
df['City'].sample(40)
# Out:
# 4159              Sydney
# 495               Oxnard
# 4401              Sydney
# 750        New York City
# 564       Pembroke Pines
# 3787              Sydney
# 2418        Philadelphia
# 5461              Sydney
# 2533         Tallahassee
# 474               Lorain
# 4069              Sydney
# 337               Dublin
# 4234              Sydney
# 5236              Sydney
# 4508              Sydney
# 248              Seattle
# 2111             Houston
# 5386              Sydney
# 4408              Sydney
# 737         Philadelphia
# 4896              Sydney
# 4769              Sydney
# 438        San Francisco
# 156        New York City
# 78         New York City
# 1085             Phoenix
# 5591              Sydney
# 1107           Arlington
# 4059              Sydney
# 1457               Salem
# 5227              Sydney
# 196              Houston
# 397        Oklahoma City
# 2683    Dearborn Heights
# 2878           Melbourne
# 744         Philadelphia
# 1982             Seattle
# ...

# %% [markdown]
# # State

# %%
df['State'].unique()
# Out:
# array(['California', 'Washington', 'Kentucky', 'Texas', 'Tennessee',
#        'Ohio', 'Nebraska', 'Massachusetts', 'Arkansas', 'Indiana',
#        'New York', 'Wisconsin', 'Oklahoma', 'Illinois', 'Pennsylvania',
#        'Mississippi', 'Arizona', 'Colorado', 'Virginia', 'Florida',
#        'Maryland', 'North Carolina', 'Georgia', 'Oregon', 'New Mexico',
#        'Minnesota', 'Missouri', 'Rhode Island', 'Connecticut',
#        'New Jersey', 'Utah', 'Michigan', 'South Dakota', 'Delaware',
#        'New Hampshire', 'West Virginia', 'North Dakota', 'Nevada',
#        'South Carolina', 'Louisiana', 'Kansas', 'Montana', 'Vermont',
#        'District of Columbia', 'Alabama', 'Iowa', 'Idaho', 'Wyoming',
#        'South Australia', 'Victoria', 'New South Wales',
#        'Western Australia', 'Queensland', 'Tasmania',
#        'Australian Capital Territory', 'Northern Territory'], dtype=object)

# %%
df['State']=(df['State']
            .astype('string')
            .str.strip()
            .str.title()
            .replace(r'^\s*$',np.nan, regex=True)
            .astype('category')
            )
df['State'].sample(50)
# Out:
# 4087         New South Wales
# 3154         New South Wales
# 1875            Pennsylvania
# 2168                New York
# 1383              California
# 5873         New South Wales
# 2200    District Of Columbia
# 3773         New South Wales
# 1294              California
# 2176            Pennsylvania
# 2740              California
# 763                 Illinois
# 5498         New South Wales
# 4450         New South Wales
# 1108                Colorado
# 4573         New South Wales
# 1676          North Carolina
# 5254         New South Wales
# 1810                Illinois
# 2907              Queensland
# 3532         New South Wales
# 1618                    Ohio
# 2575            Pennsylvania
# 1970              California
# 4513         New South Wales
# 4126         New South Wales
# 1742                New York
# 1928              Washington
# 5357         New South Wales
# 2149            Pennsylvania
# 4433         New South Wales
# 114                    Texas
# ...

# %% [markdown]
# # Region

# %%
df['Region'].unique()
# Out:
# array(['West', 'South', 'Central', 'East', nan, 'Other', 'North'],
#       dtype=object)

# %%
df['Region']=(df['Region']
              .astype('string')
              .str.strip()
              .str.lower()
              .replace({'nan':np.nan},regex=True)
              .replace(r'^\s*$', np.nan, regex=True)
              .str.title()
              .astype('category')

)
df['Region'].sample(50)
# Out:
# 223        West
# 1104       East
# 2552      South
# 1517       East
# 4242       West
# 2966      South
# 1151    Central
# 5758       West
# 1490    Central
# 2739       West
# 4843       West
# 178       South
# 945        East
# 1353       West
# 4490       West
# 4144       West
# 2597       East
# 1896       West
# 813        East
# 4614       West
# 4379       West
# 3286       West
# 4947       West
# 4676       West
# 5255       West
# 126        <NA>
# 2943      Other
# 444        West
# 3671       West
# 1519       West
# 754        West
# 956        West
# 2260       West
# 2732      South
# 5122       West
# 5148       West
# 5456       West
# 2223       East
# 284        East
# 1240       East
# 619       South
# 4217       West
# 4464       West
# 3322       West
# 4543       West
# 2954      Other
# 2259       East
# 3070       West
# 3965       West
# 1280       East
# Name: Region, dtype: category
# ...

# %%
df['Region'].unique()
# Out:
# ['West', 'South', 'Central', 'East', <NA>, 'Other', 'North']
# Categories (6, string): [Central, East, North, Other, South, West]

# %% [markdown]
# # NA_Sales

# %%
df['NA_Sales'].unique()
# Out:
# array(['$41.49', '$29.08', '$15.85', '$15.75', '$11.27', '$23.20',
#        '$11.38', '$14.03', '$14.59', '$26.93', '$9.07', '$9.81', '9',
#        '8.94', '9.09', '14.97', '7.01', '9.43', '12.78', '4.75', '6.42',
#        '10.83', '9.54', '9.63', '8.41', '6.06', '5.57', '3.44', '6.85',
#        '9.03', '5.89', '9.67', '5.17', '5.77', '4.99', '8.25', '8.52',
#        '5.54', '6.99', '6.75', '5.98', '2.55', '4.74', '7.97', '3.8',
#        '4.4', '6.91', '3.01', '6.16', '4.23', '6.76', '4.02', '4.89',
#        '2.96', '4.76', '5.99', '4.34', '5.08', '6.05', '6.72', '7.03',
#        '5.55', '3.66', '6.63', '4.09', '5.84', '3.88', '5.91', '4.36',
#        '5.58', '2.01', '4.46', '5.03', '3.54', '1.11', '1.79', '6.82',
#        '3.81', '2.91', '1.06', '0.98', '5.8', '2.58', '2.28', '2.82',
#        '7.28', '2.9', '2.93', '2.8', '4.1', '3.78', '5.39', '3.24',
#        '4.79', '3.83', '4.52', '3.51', '2.85', '3.27', '3.68', '4.41',
# ...

# %%
df['NA_Sales'].sample(50)
# Out:
# 1868      0.44
# 1666      0.78
# 4487      0.34
# 2327      0.42
# 2367      0.44
# 1137       0.6
# 2274      0.16
# 286       3.36
# 1697      0.49
# 1885      0.24
# 1813       0.7
# 4797      0.38
# 2321      0.27
# 4732      0.24
# 1784         0
# 3610      0.34
# 5112      0.34
# 4878      0.19
# 4627         0
# 3253      0.35
# 2926      0.54
# 4845      0.22
# 5442      0.17
# 1958         0
# 2983      0.34
# 3670         0
# 1578         0
# 2402      0.48
# 2579      0.62
# 4416      0.22
# 2551      0.45
# 4491      0.31
# 2162      0.38
# 8       $14.59
# 4960      0.24
# 2549      0.06
# 5838      0.22
# 1252      0.65
# 1661      0.59
# 2858      0.23
# 3915      0.28
# 1833      0.63
# 1594      0.49
# 2140      0.37
# 1814      1.01
# 178       3.02
# 1908      0.53
# 2174      0.47
# 2137      0.88
# 3868         0
# Name: NA_Sales, dtype: object

# %%
df['NA_Sales']=pd.to_numeric(df['NA_Sales']
               .astype('string')
               .str.strip()
               .str.replace(r'[^\d.]','', regex=True),
                errors='coerce')
df['NA_Sales'].head(10)
# Out:
# 0     41.49
# 1     29.08
# 2     15.85
# 3     15.75
# 4     11.27
# 5      23.2
# 6     11.38
# 7     14.03
# 8     14.59
# 13    26.93
# Name: NA_Sales, dtype: Float64

# %%
df.loc[ (df['NA_Sales']<0) | (df['NA_Sales']>100), 'NA_Sales']=np.nan

# %% [markdown]
# # Global_Sales

# %%
df['Global_Sales'].unique()
# Out:
# array([82.74, 40.24, 35.82, 33.  , 31.37, 30.26, 30.01, 29.02, 28.62,
#        28.31, 24.76, 23.42, 23.1 , 22.72, 22.  , 21.82, 21.4 , 20.81,
#        20.61, 20.22, 18.36, 18.14, 17.28, 16.38, 16.15, 15.85, 15.32,
#        15.3 , 14.98, 14.76, 14.64, 14.35, 14.24, 14.03, 13.73, 13.51,
#        13.46, 13.1 , 13.04, 12.73, 12.27, 12.21, 12.14, 11.98, 11.9 ,
#        11.89, 11.66, 11.52, 11.33, 11.18, 11.02, 10.95, 10.79, 10.77,
#        10.69, 10.57, 10.55, 10.49, 10.42, 10.26, 10.21,  9.88,  9.87,
#         9.82,  9.76,  9.72,  9.59,  9.52,  9.49,  9.32,  9.3 ,  9.2 ,
#         9.09,  9.02,  8.84,  8.76,  8.49,  8.42,  8.33,  8.24,  8.11,
#         8.09,  8.06,  8.05,  7.86,  7.84,  7.81,  7.72,  7.69,  7.67,
#         7.6 ,  7.58,  7.46,  7.45,  7.37,  7.34,  7.31,  7.3 ,  7.27,
#         7.23,  7.2 ,  7.16,  7.13,  7.07,  6.96,  6.95,  6.91,  6.9 ,
#         6.83,  6.82,  6.81,  6.76,  6.73,  6.72,  6.69,  6.67,  6.6 ,
# ...

# %%
df['Global_Sales']=pd.to_numeric(df['Global_Sales']
            .replace(r'[^\d.]','', regex=True),
            errors='coerce')

df['Global_Sales'].head(10)
# Out:
# 0     82.74
# 1     40.24
# 2     35.82
# 3     33.00
# 4     31.37
# 5     30.26
# 6     30.01
# 7     29.02
# 8     28.62
# 13    28.31
# Name: Global_Sales, dtype: float64

# %%
df.loc[ (df['Global_Sales']<0) | (df['Global_Sales']>100), 'Global_Sales']=np.nan

# %% [markdown]
# # NA_Profit

# %%
df['NA_Profit'].unique()
# Out:
# array([1.2447e+01, 8.7240e+00, 4.7550e+00, 4.7250e+00, 3.3810e+00,
#        6.9600e+00, 3.4140e+00, 4.2090e+00, 4.3770e+00, 8.0790e+00,
#        2.7210e+00, 2.9430e+00, 2.7000e+00, 2.6820e+00, 2.7270e+00,
#        4.4910e+00, 2.1030e+00, 2.8290e+00, 3.8340e+00, 1.4250e+00,
#        1.9260e+00, 3.2490e+00, 2.8620e+00, 2.8890e+00, 2.5230e+00,
#        1.8180e+00, 1.6710e+00, 1.0320e+00, 2.0550e+00, 2.7090e+00,
#        1.7670e+00, 2.9010e+00, 1.5510e+00, 1.7310e+00, 1.4970e+00,
#        2.4750e+00, 2.5560e+00, 1.6620e+00, 2.0970e+00, 2.0250e+00,
#        1.7940e+00, 7.6500e-01, 1.4220e+00, 2.3910e+00, 1.1400e+00,
#        1.3200e+00, 2.0730e+00, 9.0300e-01, 1.8480e+00, 1.2690e+00,
#        2.0280e+00, 1.2060e+00, 1.4670e+00, 8.8800e-01, 1.4280e+00,
#        1.7970e+00, 1.3020e+00, 1.5240e+00, 1.8150e+00, 2.0160e+00,
#        2.1090e+00, 1.6650e+00, 1.0980e+00, 1.9890e+00, 1.2270e+00,
#        1.7520e+00, 1.1640e+00, 1.7730e+00, 1.3080e+00, 1.6740e+00,
# ...

# %%
df['NA_Profit']=(pd.to_numeric(df['NA_Profit']
    .replace(r'[\d.]', '', regex=True),
    errors='coerce').round(2)
)
df['NA_Profit'].sample(10)
# Out:
# 683     0.00
# 1257    0.07
# 354     0.18
# 711     0.11
# 2335    0.13
# 3574    0.07
# 2413    0.14
# 375     0.64
# 4130    0.07
# 1757    0.29
# Name: NA_Profit, dtype: float64

# %%
df.loc[ (df['NA_Profit']<0) | (df['NA_Profit']>100), 'NA_Profit']=np.nan

# %% [markdown]
# # Global_Profit

# %%
df['Global_Profit'].unique()
# Out:
# array([24.822, 12.072, 10.746,  9.9  ,  9.411,  9.078,  9.003,  8.706,
#         8.586,  8.493,  7.428,  7.026,  6.93 ,  6.816,  6.6  ,  6.546,
#         6.42 ,  6.243,  6.183,  6.066,  5.508,  5.442,  5.184,  4.914,
#         4.845,  4.755,  4.596,  4.59 ,  4.494,  4.428,  4.392,  4.305,
#         4.272,  4.209,  4.119,  4.053,  4.038,  3.93 ,  3.912,  3.819,
#         3.681,  3.663,  3.642,  3.594,  3.57 ,  3.567,  3.498,  3.456,
#         3.399,  3.354,  3.306,  3.285,  3.237,  3.231,  3.207,  3.171,
#         3.165,  3.147,  3.126,  3.078,  3.063,  2.964,  2.961,  2.946,
#         2.928,  2.916,  2.877,  2.856,  2.847,  2.796,  2.79 ,  2.76 ,
#         2.727,  2.706,  2.652,  2.628,  2.547,  2.526,  2.499,  2.472,
#         2.433,  2.427,  2.418,  2.415,  2.358,  2.352,  2.343,  2.316,
#         2.307,  2.301,  2.28 ,  2.274,  2.238,  2.235,  2.211,  2.202,
#         2.193,  2.19 ,  2.181,  2.169,  2.16 ,  2.148,  2.139,  2.121,
# ...

# %%
df['Global_Profit']=(pd.to_numeric(df['Global_Profit']
    .replace(r'[^\d.]', '', regex=True),
    errors='coerce').round(2)
)
df['Global_Profit'].head(10)
# Out:
# 0     24.82
# 1     12.07
# 2     10.75
# 3      9.90
# 4      9.41
# 5      9.08
# 6      9.00
# 7      8.71
# 8      8.59
# 13     8.49
# Name: Global_Profit, dtype: float64

# %%
df.loc[ (df['Global_Profit']<0) | (df['Global_Profit']>100), 'Global_Profit']=np.nan

# %% [markdown]
# # Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5893 entries, 0 to 5908
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5893 non-null   int64
#  1   Name           5893 non-null   string
#  2   Platform       5893 non-null   category
#  3   Year           5893 non-null   int64
#  4   Month          5893 non-null   category
#  5   Genre          5893 non-null   category
#  6   Publisher      5851 non-null   category
#  7   Country        5893 non-null   category
#  8   City           5893 non-null   category
#  9   State          5893 non-null   category
#  10  Region         5866 non-null   category
#  11  NA_Sales       5893 non-null   Float64
#  12  Global_Sales   5893 non-null   float64
#  13  NA_Profit      5893 non-null   float64
#  14  Global_Profit  5893 non-null   float64
# dtypes: Float64(1), category(8), float64(3), int64(2), string(1)
# memory usage: 457.4 KB

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year              0
# Month             0
# Genre             0
# Publisher        42
# Country           0
# City              0
# State             0
# Region           27
# NA_Sales          0
# Global_Sales      0
# NA_Profit         0
# Global_Profit     0
# dtype: int64

# %%
pd.set_option('display.max_rows',None)
df[df.isna().any(axis=1)]
# Out:
#       Rank                                               Name Platform  Year  \
# 13      10                                          Duck Hunt      NES  2010
# 38      35                          Call Of Duty Black Ops Ii      PS3  2010
# 53      50           Pokemon Omega Rubypokemon Alpha Sapphire      3DS  2010
# 84      78                                            Fifa 16      PS4  2010
# 126    120                          Uncharted 2 Among Thieves      PS3  2010
# 210    204                 Super Smash Bros For Wii U And 3Ds     WIIU  2010
# 225    219                                    Assassins Creed      PS3  2010
# 243    237                                     The Last Of Us      PS4  2010
# 480    471                          Wwe Smackdown Vs Raw 2006      PS2  2010
# 950    942                    Gran Turismo Concept 2001 Tokyo      PS2  2011
# 1313  1305                                     Triple Play 99       PS  2013
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df.dropna()  # After dropping null 69 values Total 5893 - 69=5824
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      WII  2010   Jan
# 1        2                           Super Mario Bros      NES  2010   Feb
# 2        3                             Mario Kart Wii      WII  2010   Mar
# 3        4                          Wii Sports Resort      WII  2010   Apr
# 4        5                    Pokemon Redpokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                    Crazy Taxi Catch A Ride      GBA  2017   Sep
# 5905  5891                               Mysims Party       DS  2017   Oct
# 5906  5892  Harry Potter And The Order Of The Phoenix     X360  2017   Nov
# 5907  5893                   Skylanders Superchargers      PS4  2017   Dec
# 5908  5894                Macross Digital Mission Vfx       PS  2017   Jan
#
#              Genre           Publisher    Country        City  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
col=df.columns.drop('Rank')
col
# Out:
# Index(['Name', 'Platform', 'Year', 'Month', 'Genre', 'Publisher', 'Country',
#        'City', 'State', 'Region', 'NA_Sales', 'Global_Sales', 'NA_Profit',
#        'Global_Profit'],
#       dtype='object')

# %%
df.duplicated(subset=col).sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Rank                      int64
# Name             string[python]
# Platform               category
# Year                      int64
# Month                  category
# Genre                  category
# Publisher              category
# Country                category
# City                   category
# State                  category
# Region                 category
# NA_Sales                Float64
# Global_Sales            float64
# NA_Profit               float64
# Global_Profit           float64
# dtype: object

# %%
df.value_counts()
# Out:
# Rank  Name                                        Platform  Year  Month  Genre       Publisher              Country    City           State            Region  NA_Sales  Global_Sales  NA_Profit  Global_Profit
# 1     Wii Sports                                  WII       2010  Jan    Sports      Nintendo               USA        Fairfield      California       West    41.49     82.74         12.45      24.82            1
# 3934  Burnout Revenge                             X360      2014  Sep    Racing      Electronic Arts        Australia  Sydney         New South Wales  West    0.42      0.51          0.13       0.15             1
# 3932  The Bigs                                    PS2       2014  Jul    Sports      Take Two Interactive   Australia  Sydney         New South Wales  West    0.25      0.51          0.08       0.15             1
# ...

# %%
df.shape
# Out:
# (5893, 15)

# %%
(df.isnull().sum()/len(df)*100).round(2)
# Out:
# Rank             0.00
# Name             0.00
# Platform         0.00
# Year             0.00
# Month            0.00
# Genre            0.00
# Publisher        0.71
# Country          0.00
# City             0.00
# State            0.00
# Region           0.46
# NA_Sales         0.00
# Global_Sales     0.00
# NA_Profit        0.00
# Global_Profit    0.00
# dtype: float64

# %%
pd.set_option('display.max_rows',None)
df[df.isnull().any(axis=1)]
# Out:
#       Rank                                               Name Platform  Year  \
# 13      10                                          Duck Hunt      NES  2010
# 38      35                          Call Of Duty Black Ops Ii      PS3  2010
# 53      50           Pokemon Omega Rubypokemon Alpha Sapphire      3DS  2010
# 84      78                                            Fifa 16      PS4  2010
# 126    120                          Uncharted 2 Among Thieves      PS3  2010
# 210    204                 Super Smash Bros For Wii U And 3Ds     WIIU  2010
# 225    219                                    Assassins Creed      PS3  2010
# 243    237                                     The Last Of Us      PS4  2010
# 480    471                          Wwe Smackdown Vs Raw 2006      PS2  2010
# 950    942                    Gran Turismo Concept 2001 Tokyo      PS2  2011
# 1313  1305                                     Triple Play 99       PS  2013
# ...

# %%
df[df['Publisher'].isnull()]
# Out:
#       Rank                                               Name Platform  Year  \
# 480    471                          Wwe Smackdown Vs Raw 2006      PS2  2010
# 950    942                    Gran Turismo Concept 2001 Tokyo      PS2  2011
# 1313  1305                                     Triple Play 99       PS  2013
# 1662  1651                                Nascar Thunder 2003      PS2  2015
# 1675  1664           Shrek Shrek 2 2In1 Gameboy Advance Video      GBA  2011
# 2127  2116                                       Suikoden Iii      PS2  2012
# 2186  2175                                   Wheel Of Fortune      PS2  2012
# 2235  2224                                  Bentleys Hackpack      GBA  2012
# 2249  2238                       Teenage Mutant Ninja Turtles      GBA  2012
# 2299  2288                                       Namco Museum       XB  2012
# 2308  2297                                      Rhythm Heaven      WII  2012
# ...

# %%
df[df['Region'].isna()]
# Out:
#       Rank                                       Name Platform  Year Month  \
# 13      10                                  Duck Hunt      NES  2010   Oct
# 38      35                  Call Of Duty Black Ops Ii      PS3  2010   Nov
# 53      50   Pokemon Omega Rubypokemon Alpha Sapphire      3DS  2010   Feb
# 84      78                                    Fifa 16      PS4  2010   Jun
# 126    120                  Uncharted 2 Among Thieves      PS3  2010   Dec
# 210    204         Super Smash Bros For Wii U And 3Ds     WIIU  2010   Dec
# 225    219                            Assassins Creed      PS3  2010   Mar
# 243    237                             The Last Of Us      PS4  2010   Sep
# 2453  2442  Harry Potter And The Order Of The Phoenix       DS  2013   May
# 2454  2443                         Rampage World Tour       PS  2013   Jun
# 2455  2444                            Burnout Legends      PSP  2013   Jul
# ...

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# # fillna()

# %%
# Publisher - 42 -> fillna with Unknown Publisher
# Region - 27 -> fillna with Unknown Region

# %%
# For Categories we dont change directly so convert them into string - after filling - back to same data type
cols=['Publisher','Region']
df[cols]=df[cols].astype('string')

df.fillna({
    'Publisher':'Unknown Publisher',
    'Region':'Unknown Region'
}, inplace=True)

df[cols]=df[cols].astype('category')

df.isna().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Month            0
# Genre            0
# Publisher        0
# Country          0
# City             0
# State            0
# Region           0
# NA_Sales         0
# Global_Sales     0
# NA_Profit        0
# Global_Profit    0
# dtype: int64

# %%
df.shape
# Out:
# (5893, 15)

# %%
df
# Out:
#       Rank                                       Name Platform  Year Month  \
# 0        1                                 Wii Sports      WII  2010   Jan
# 1        2                           Super Mario Bros      NES  2010   Feb
# 2        3                             Mario Kart Wii      WII  2010   Mar
# 3        4                          Wii Sports Resort      WII  2010   Apr
# 4        5                    Pokemon Redpokemon Blue       GB  2010   May
# ...    ...                                        ...      ...   ...   ...
# 5904  5890                    Crazy Taxi Catch A Ride      GBA  2017   Sep
# 5905  5891                               Mysims Party       DS  2017   Oct
# 5906  5892  Harry Potter And The Order Of The Phoenix     X360  2017   Nov
# 5907  5893                   Skylanders Superchargers      PS4  2017   Dec
# 5908  5894                Macross Digital Mission Vfx       PS  2017   Jan
#
#              Genre           Publisher    Country        City  \
# ...

# %%
df.rename(columns={'NA_Sales':'USA_Sales', 'NA_Profit':'USA_Profit'}, inplace=True)
df.head(10)
# Out:
#     Rank                      Name Platform  Year Month         Genre  \
# 0      1                Wii Sports      WII  2010   Jan        Sports
# 1      2          Super Mario Bros      NES  2010   Feb      Platform
# 2      3            Mario Kart Wii      WII  2010   Mar        Racing
# 3      4         Wii Sports Resort      WII  2010   Apr        Sports
# 4      5   Pokemon Redpokemon Blue       GB  2010   May  Role Playing
# 5      6                    Tetris       GB  2010   Jun        Puzzle
# 6      7      New Super Mario Bros       DS  2010   Jul      Platform
# 7      8                  Wii Play      WII  2010   Aug          Misc
# 8      9  New Super Mario Bros Wii      WII  2010   Sep      Platform
# 13    10                 Duck Hunt      NES  2010   Oct       Shooter
#
#    Publisher Country        City       State          Region  USA_Sales  \
# 0   Nintendo     USA   Fairfield  California            West      41.49
# ...

# %%
df.to_csv('CleanedVideoGameSaleData.csv', index=False)

# %%
# 1> I performed detailed data cleaning on the Video Game Sales dataset, starting with understanding its structure and 
# removing duplicate records.
    
# 2> I standardized the data by fixing extra spaces, correcting capitalization, and ensuring proper data types and date formats.
    
# 3> I handled missing values, validated categories, corrected spelling errors, and verified unique values for consistency.
    
# 4> Finally, I resolved logical errors and treated outliers to make the dataset accurate, reliable, and ready for analysis.
